# %%
import pandas as pd
import numpy as np

df=pd.read_csv("instagram_usage_lifestyle.csv")
df
# Out:
#        user_id   app_name  age      gender         country urban_rural  \
# 0            1  Instagram   51      Female           India       Rural
# 1            2  Instagram   64      Female  United Kingdom       Urban
# 2            3  Instagram   41      Female          Canada       Urban
# 3            4  Instagram   27  Non-binary     South Korea       Urban
# 4            5  Instagram   55        Male           India       Urban
# ...        ...        ...  ...         ...             ...         ...
# 25987    25988  Instagram   32        Male     South Korea    Suburban
# 25988    25989  Instagram   28        Male           India    Suburban
# 25989    25990  Instagram   22        Male     South Korea       Urban
# 25990    25991  Instagram   46        Male           Other       Urban
# 25991    25992  Instagram   55      Female  United Kingdom       Urban
#
#        income_level   employment_status education_level relationship_status  \
# ...

# %%
df.head()
# Out:
#    user_id   app_name  age      gender         country urban_rural  \
# 0        1  Instagram   51      Female           India       Rural
# 1        2  Instagram   64      Female  United Kingdom       Urban
# 2        3  Instagram   41      Female          Canada       Urban
# 3        4  Instagram   27  Non-binary     South Korea       Urban
# 4        5  Instagram   55        Male           India       Urban
#
#    income_level   employment_status education_level relationship_status  ...  \
# 0          High             Retired      Bachelor’s              Single  ...
# 1        Middle  Full-time employed           Other            Divorced  ...
# 2        Middle             Student      Bachelor’s   In a relationship  ...
# 3        Middle          Unemployed        Master’s   In a relationship  ...
# 4  Upper-middle  Full-time employed      Bachelor’s              Single  ...
#
#   last_login_date  average_session_length_minutes  content_type_preference  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25992 entries, 0 to 25991
# Data columns (total 58 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   user_id                         25992 non-null  int64
#  1   app_name                        25992 non-null  object
#  2   age                             25992 non-null  int64
#  3   gender                          25992 non-null  object
#  4   country                         25992 non-null  object
#  5   urban_rural                     25992 non-null  object
#  6   income_level                    25992 non-null  object
#  7   employment_status               25992 non-null  object
#  8   education_level                 25992 non-null  object
#  9   relationship_status             25992 non-null  object
#  10  has_children                    25991 non-null  object
#  11  exercise_hours_per_week         25991 non-null  float64
# ...

# %%
df.nunique()
# Out:
# user_id                           25992
# app_name                              1
# age                                  53
# gender                                4
# country                              10
# urban_rural                           3
# income_level                          5
# employment_status                     6
# education_level                       6
# relationship_status                   6
# has_children                          2
# exercise_hours_per_week             218
# sleep_hours_per_night                71
# diet_quality                          5
# smoking                               3
# alcohol_frequency                     5
# perceived_stress_score               41
# self_reported_happiness              10
# body_mass_index                     243
# blood_pressure_systolic              70
# blood_pressure_diastolic             40
# daily_steps_count                   587
# weekly_work_hours                   629
# ...

# %%
df.isna().sum()
# Out:
# user_id                           0
# app_name                          0
# age                               0
# gender                            0
# country                           0
# urban_rural                       0
# income_level                      0
# employment_status                 0
# education_level                   0
# relationship_status               0
# has_children                      1
# exercise_hours_per_week           1
# sleep_hours_per_night             1
# diet_quality                      1
# smoking                           1
# alcohol_frequency                 1
# perceived_stress_score            1
# self_reported_happiness           1
# body_mass_index                   1
# blood_pressure_systolic           1
# blood_pressure_diastolic          1
# daily_steps_count                 1
# weekly_work_hours                 1
# hobbies_count                     1
# social_events_per_month           1
# books_read_per_year               1
# ...

# %%
df_clean=df.dropna()

# %%
df_clean.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df_clean["daily_active_minutes_instagram"] >= 120
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 25986     True
# 25987    False
# 25988     True
# 25989     True
# 25990     True
# Name: daily_active_minutes_instagram, Length: 25991, dtype: bool

# %%
(df_clean["daily_active_minutes_instagram"] >= 120).sum()
# Out:
# np.int64(18251)

# %%
df_clean["activity_level"] = "Highly Active"

df_clean["activity_level"] = df_clean["activity_level"].where(
    df_clean["daily_active_minutes_instagram"] >= 120,
    "Normal"
)
# Out:
# /tmp/ipython-input-451816072.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["activity_level"] = "Highly Active"
# /tmp/ipython-input-451816072.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["activity_level"] = df_clean["activity_level"].where(

# %%
df_clean[["daily_active_minutes_instagram", "activity_level"]].head()
# Out:
#    daily_active_minutes_instagram activity_level
# 0                             5.0         Normal
# 1                            74.0         Normal
# 2                             5.0         Normal
# 3                           233.0  Highly Active
# 4                           184.0  Highly Active

# %%
df_clean["engagement_flag"]="Good"

df_clean["engagement_flag"]=df_clean["engagement_flag"].where(
    df_clean["user_engagement_score"] >= 5,"Low")
# Out:
# /tmp/ipython-input-1986961289.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["engagement_flag"]="Good"
# /tmp/ipython-input-1986961289.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["engagement_flag"]=df_clean["engagement_flag"].where(

# %%
df_clean[["user_engagement_score", "engagement_flag"]].head()
# Out:
#    user_engagement_score engagement_flag
# 0                   7.83            Good
# 1                   1.43             Low
# 2                   9.67            Good
# 3                   0.94             Low
# 4                   1.03             Low

# %%
df_clean["High_Value_User"]="yes"

df_clean["High_Value_User"]=df_clean["High_Value_User"].where(
    (df_clean["activity_level"] == "Highly Active") & (df_clean["engagement_flag"] == "Good"),
    "No")
# Out:
# /tmp/ipython-input-3548150257.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["High_Value_User"]="yes"
# /tmp/ipython-input-3548150257.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["High_Value_User"]=df_clean["High_Value_User"].where(

# %%
df_clean[["High_Value_User", "activity_level","engagement_flag"]].head()
# Out:
#   High_Value_User activity_level engagement_flag
# 0              No         Normal            Good
# 1              No         Normal             Low
# 2              No         Normal            Good
# 3              No  Highly Active             Low
# 4              No  Highly Active             Low

# %%
df_clean.columns
# Out:
# Index(['user_id', 'app_name', 'age', 'gender', 'country', 'urban_rural',
#        'income_level', 'employment_status', 'education_level',
#        'relationship_status', 'has_children', 'exercise_hours_per_week',
#        'sleep_hours_per_night', 'diet_quality', 'smoking', 'alcohol_frequency',
#        'perceived_stress_score', 'self_reported_happiness', 'body_mass_index',
#        'blood_pressure_systolic', 'blood_pressure_diastolic',
#        'daily_steps_count', 'weekly_work_hours', 'hobbies_count',
#        'social_events_per_month', 'books_read_per_year',
#        'volunteer_hours_per_month', 'travel_frequency_per_year',
#        'daily_active_minutes_instagram', 'sessions_per_day',
#        'posts_created_per_week', 'reels_watched_per_day',
#        'stories_viewed_per_day', 'likes_given_per_day',
#        'comments_written_per_day', 'dms_sent_per_week',
#        'dms_received_per_week', 'ads_viewed_per_day', 'ads_clicked_per_day',
# ...

# %%
df_clean["High_Value_User"].value_counts(dropna=False)
# Out:
# High_Value_User
# No    25991
# Name: count, dtype: int64

# %%
high_active=df_clean[df_clean["activity_level"]=="Highly Active"]
high_active[["user_id", "daily_active_minutes_instagram", "activity_level"]].head()
# Out:
#    user_id  daily_active_minutes_instagram activity_level
# 3        4                           233.0  Highly Active
# 4        5                           184.0  Highly Active
# 6        7                           125.0  Highly Active
# 7        8                           282.0  Highly Active
# 8        9                           128.0  Highly Active

# %%
high_active_count=(df_clean["activity_level"]=="Highly Active").sum()

# %%
high_active_count
# Out:
# np.int64(18251)

# %%
Ads=df_clean[(df_clean["activity_level"]=="Highly Active") & (df_clean["engagement_flag"]=="Good")]
Ads.head()
# Out:
# Empty DataFrame
# ...

# %%
df_clean["engagement_flag"].value_counts()
# Out:
# engagement_flag
# Low     24486
# Good     1505
# Name: count, dtype: int64

# %%
df_clean["activity_level"].value_counts()
# Out:
# activity_level
# Highly Active    18251
# Normal            7740
# Name: count, dtype: int64

# %%
Creator=df_clean[(df_clean["activity_level"]=="Highly Active") | (df_clean["engagement_flag"]=="Good")]
Creator.head()
# Out:
#    user_id   app_name  age      gender      country urban_rural  income_level  \
# 0        1  Instagram   51      Female        India       Rural          High
# 2        3  Instagram   41      Female       Canada       Urban        Middle
# 3        4  Instagram   27  Non-binary  South Korea       Urban        Middle
# 4        5  Instagram   55        Male        India       Urban  Upper-middle
# 6        7  Instagram   33  Non-binary        Japan       Urban  Lower-middle
#
#     employment_status education_level relationship_status  ...  \
# 0             Retired      Bachelor’s              Single  ...
# 2             Student      Bachelor’s   In a relationship  ...
# 3          Unemployed        Master’s   In a relationship  ...
# 4  Full-time employed      Bachelor’s              Single  ...
# 6          Freelancer     High school   In a relationship  ...
#
#   preferred_content_theme  privacy_setting_level  two_factor_auth_enabled  \
# ...

# %%
condition=((df_clean["activity_level"]=="Highly Active") | (df_clean["engagement_flag"]=="Good"))

# %%
high_engagement_count=condition.sum()

# %%
high_engagement_count
# Out:
# np.int64(19756)

# %%
df_clean["Creator_flag"]="creator"
df_clean["Creator_flag"]=df_clean["Creator_flag"].where((df_clean["activity_level"] == "Highly Active") | (df_clean["engagement_flag"] == "Good"),
    "normal_user")
# Out:
# /tmp/ipython-input-1139864336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["Creator_flag"]="creator"
# /tmp/ipython-input-1139864336.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["Creator_flag"]=df_clean["Creator_flag"].where((df_clean["activity_level"] == "Highly Active") | (df_clean["engagement_flag"] == "Good"),

# %%
df_clean[["activity_level", "engagement_flag", "Creator_flag"]].head()
# Out:
#   activity_level engagement_flag Creator_flag
# 0         Normal            Good      creator
# 1         Normal             Low  normal_user
# 2         Normal            Good      creator
# 3  Highly Active             Low      creator
# 4  Highly Active             Low      creator

# %%
df_clean["Creator_flag"].value_counts()
# Out:
# Creator_flag
# creator        19756
# normal_user     6235
# Name: count, dtype: int64

# %%
(df_clean["Creator_flag"] == "creator").sum()
# Out:
# np.int64(19756)

# %%
creators_df = df_clean[df_clean["Creator_flag"] == "Creator"]

# %%
creators_df["gender"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
import seaborn as sns

# %%
sns.countplot(x="Creator_flag", data=df_clean)
# Out:
# <Axes: xlabel='Creator_flag', ylabel='count'>

# %%
sns.countplot(
    x="activity_level",
    hue="Creator_flag",
    data=df_clean
)
# Out:
# <Axes: xlabel='activity_level', ylabel='count'>
